# %% [markdown]
# <a href="https://colab.research.google.com/github/EmanKorim/Predicit-NDVI/blob/master/Predicit_NDVI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Authenticate to Colab and Cloud**
#
# Identify yourself to Google Cloud, so you have access to storage and other resources. When you run the code below, it will display a link in the output to an authentication page in your browser. Follow the link to a page that will let you grant permission to the Cloud SDK to access your resources. Copy the code from the permissions page back into this notebook and press return to complete the process.
#
# (You may need to run this again if you get a credentials error later.)

# %%
from google.colab import auth

auth.authenticate_user()

# %% [markdown]
# **Authenticate to Earth Engine and initialize**
#
# Import the Earth Engine API and authenticate to Earth Engine the same way you did to the Colab notebook. Specifically, run the code to display a link to a permissions page. This gives you access to your Earth Engine account. Copy the code from the Earth Engine permissions page back into the notebook and press return to complete the process. The final line initializes the Earth Engine API.

# %%
# Import the Earth Engine API and initialize it.
import ee

# Trigger the authentication flow.
ee.Authenticate()

# Initialize the library.
ee.Initialize()
# Out:
# To authorize access needed by Earth Engine, open the following URL in a web browser and follow the instructions. If the web browser does not start automatically, please manually browse the URL below.
#
#     https://accounts.google.com/o/oauth2/auth?client_id=517222506229-vsmmajv00ul0bs7p89v5m89qs8eb9359.apps.googleusercontent.com&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fearthengine+https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdevstorage.full_control&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&response_type=code
#
# The authorization workflow will generate a code, which you should paste in the box below.
# Enter verification code: 4/wAEz6PCbXbQHh33lu6OYZFi0H4TnQCl2uobxSnc2C707h7MyswpJ0To
#
# Successfully saved authorization token.

# %%
# %tensorflow_version 2.x
import tensorflow as tf

#Get NDVI data from Google Earth Engine
NDVILandSat = ee.ImageCollection('LANDSAT/LC08/C01/T1_8DAY_NDVI');
ee.Geometry()

#Get NDVI Region of Interest 
NDVILandSatROI = NDVILandSat.map(function(image){return image.clip(geometry)});

NDVILandSatROI2= NDVILandSatROI.qualityMosaic("NDVI");
print(NDVILandSatROI2);
# Out:
#   File "<ipython-input-6-81725e17b281>", line 8
#     NDVILandSatROI = NDVILandSat.map(function(image){return image.clip(geometry)});
#                                                     ^
# SyntaxError: invalid syntax

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
#Read NDVI Region of Interest after uploading the file in runtime
NDVILandSatROI=tf.io.read_file('/NDVILandSatROI.tfrecord');
# Out:
# tf.Tensor(b'\xb2\x00\x00\x00\x00\x00\x00\x00\'1\x9e\x07\n\xaf\x01\n\x1d\n\x11system:time_start\x12\x08\x12\x06\n\x04\xe5\xf0\x9eS\n\x1b\n\x0fsystem:time_end\x12\x08\x12\x06\n\x04\x7f\x05\x9fS\n\x1a\n\x0esystem:version\x12\x08\x12\x06\n\x04q\xb0\xb3X\n7\n\tsystem:id\x12*\n(\n&LANDSAT/LC08/C01/T1_8DAY_NDVI/20130407\n\x1c\n\x0csystem:index\x12\x0c\n\n\n\x0820130407\xb8\xe5\x8b\xe8\xb2\x00\x00\x00\x00\x00\x00\x00\'1\x9e\x07\n\xaf\x01\n\x1d\n\x11system:time_start\x12\x08\x12\x06\n\x04\x7f\x05\x9fS\n\x1b\n\x0fsystem:time_end\x12\x08\x12\x06\n\x04\x18\x1a\x9fS\n\x1a\n\x0esystem:version\x12\x08\x12\x06\n\x04q\xb0\xb3X\n7\n\tsystem:id\x12*\n(\n&LANDSAT/LC08/C01/T1_8DAY_NDVI/20130415\n\x1c\n\x0csystem:index\x12\x0c\n\n\n\x0820130415\xd3:\x85\xf1\xb2\x00\x00\x00\x00\x00\x00\x00\'1\x9e\x07\n\xaf\x01\n\x1d\n\x11system:time_start\x12\x08\x12\x06\n\x04\x18\x1a\x9fS\n\x1b\n\x0fsystem:time_end\x12\x08\x12\x06\n\x04\xb2.\x9fS\n\x1a\n\x0esystem:version\x12\x08\x12\x06\n\x04q\xb0\xb3X\n7\n\tsystem:id\x1
# ...
